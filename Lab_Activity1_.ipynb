# %% [markdown]
# <a href="https://colab.research.google.com/github/Gilmore-Floyd-R-Lozano/OOP-58001/blob/main/Lab_Activity1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = 20
total_numbers = n
sum = 0
average = 0
while n>=0:
  sum +=n
  n-=1
print("Sum = ",sum)
average = sum / total_numbers
print("Average = ",average)
# Out:
# Sum =  210
# Average =  10.5

# %% [markdown]
# ![Lab Activity 1.png](data:image/png;base64,...)
